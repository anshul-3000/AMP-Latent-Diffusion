# %% [markdown]
# first prepare the latent vectors for diffusion

# %%
import numpy as np

latent_vectors = np.load(
    "../diffusion/amp_latent_vectors.npy"
)

print(latent_vectors.shape)

print("Mean:", latent_vectors.mean())
print("Std :", latent_vectors.std())
print("Min :", latent_vectors.min())
print("Max :", latent_vectors.max())
# Out:
# (8400, 128)
# Mean: -0.02482663
# Std : 0.36211887
# Min : -1.7336204
# Max : 1.7671183

# %% [markdown]
# Multiple decoder architectures failed to reconstruct peptide sequences accurately from the compressed latent representation, suggesting that the learned latent space is optimized for peptide representation rather than exact sequence recovery.
